# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv(r"C:\Users\sesay\Desktop\all scientific programming\tested.csv")
data.head()
# Out:
#                Name  Age Gender   Injured      Hospital Admitted_Date  \
# 0       John kamara   34      M  Critical     Connaught     11/5/2021
# 1     Mariama Sesay   22      F  Moderate   34 Military     11/6/2021
# 2   Fatmata Bangura   41      F  Critical     Connaught     11/7/2021
# 3    Ibrahim Korama   19      M    Severe     Emergency     11/8/2021
# 4  Abubakarr Conteh   29      M     Minor  St Macauley      11/9/2021
#
#    Survival  Death  Days_Hospitalize
# 0         0      1                 2
# 1         1      0                14
# 2         0      1                 1
# 3         1      0                28
# 4         1      0                 0

# %%
y1_column = data.columns[8]
y2_column = data.columns[6]

mean_value = data[y1_column].mean()
median_value = data[y1_column].median()
mode_value = data[y1_column].mode()[0]
std_value = data[y1_column].std()
var_value = data[y1_column].var()


print("Days_Hospitalize ")
print(f"Mean: {mean_value}")
print(f"Median: {median_value}")
print(f"Mode: {mode_value}")
print(f"Standared Deviation: {std_value}")
print(f"Variance: {var_value}")

##################
# Out:
# Days_Hospitalize
# Mean: 10.4
# Median: 4.0
# Mode: 0
# Standared Deviation: 12.316075441702779
# Variance: 151.6857142857143

# %%
mean_value = data[y2_column].mean()
median_value = data[y2_column].median()
mode_value = data[y2_column].mode()[0]
std_value = data[y2_column].std()
var_value = data[y2_column].var()




print("Survival")
print(f"Mean: {mean_value}")
print(f"Median: {median_value}")
print(f"Mode: {mode_value}")
print(f"Standared Deviation: {std_value}")
print(f"Variance: {var_value}")
# Out:
# Survival
# Mean: 0.6
# Median: 1.0
# Mode: 1
# Standared Deviation: 0.50709255283711
# Variance: 0.2571428571428572

# %%
sns.scatterplot(x=data['Days_Hospitalize'], y=data['Survival'])

plt.show()

# %%
x = data.drop(columns=['Name','Age','Injured','Hospital','Admitted_Date','Gender','Survival','Death'])
y=data['Survival']

#

# %%
x.head()
# Out:
#    Days_Hospitalize
# 0                 2
# 1                14
# 2                 1
# 3                28
# 4                 0

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    1
# Name: Survival, dtype: int64

# %% [raw]
# #model = linearRegression()
# #model.fit(x_train, y_train)
#
# #y_pred = model.predict(x_test)

# %%
#print("R2:" , r2_score(y_test, y_pred))

#print("MSE:" , mean_squared_error(y_test, y_pred))

# %%
x.shape
# Out:
# (15, 1)

# %%
y.shape
# Out:
# (15,)

# %%
x_train, x_test, y_train,y_test = train_test_split( x,y, test_size = 0.2, random_state=11)

# %%
model = LinearRegression()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

# %%
plt.scatter(y_test,y_pred)
plt.xlabel("Days_Hospitalized")
plt.ylabel("Survival")
#plt.title(f"{y_test} Vs {y_pred}")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x_train.shape
# Out:
# (12, 1)

# %%
y_train.shape
# Out:
# (12,)

# %%
x_train.head()
# Out:
#     Days_Hospitalize
# 6                 21
# 4                  0
# 5                  3
# 13                12
# 2                  1

# %%
x_train.describe().round(3)
# Out:
#        Days_Hospitalize
# count            12.000
# mean             10.333
# std              12.302
# min               0.000
# 25%               1.000
# 50%               4.000
# 75%              15.750
# max              35.000
